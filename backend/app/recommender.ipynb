# %%
import pandas as pd

# %%
# Dataset from https://collegescorecard.ed.gov/data/
df = pd.read_csv('/Users/jessicabenitez/Documents/GitHub/college-rec/College_Scorecard_Raw_Data_04082024/MERGED2022_23_PP.csv', 
                 encoding='latin-1')
df.head(10)
# Out:
# /var/folders/4l/q8fyjl614w1567jd1msnhymw0000gn/T/ipykernel_6672/830166818.py:2: DtypeWarning: Columns (9,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984,2403,2404,2495,2496,2497,2498,2499,2500,2501,2502,2503,2504,2505,2506,2507,2508,2509,2510,2511,2512,2513,2514,2515,2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530,3215,3231,3235,3236) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/jessicabenitez/Documents/GitHub/college-rec/College_Scorecard_Raw_Data_04082024/MERGED2022_23_PP.csv',
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Columns: 3244 entries, UNITID to ACTMT50
# dtypes: float64(2703), int64(13), object(528)
# memory usage: 160.5+ MB

# %%
# showing duplicates
df.duplicated(subset='INSTNM').sum()
# Out:
# 127

# %% [markdown]
# There are 127 duplicate rows

# %%
df.drop(['INSTURL', 'NPCURL', 'SATVR50', 'SATMT50', 'ACTCM50', 'ACTEN50', 'ACTMT50', 'PCTPELL_DCS', 'PCTFLOAN_DCS',
         'DCS_PELL_LOAN', 'PCTPELL_DCS_POOLED_SUPP', 'PCTFLOAN_DCS_POOLED_SUPP', 'DCS_PELL_LOAN_POOLED', 'POOLYRS_DCS',
         'OMAWDP8_NOPELL_FIRSTTIME', 'OMENRUP_NOPELL_FIRSTTIME', 'OMENRYP_NOPELL_NOTFIRSTTIME', 'OMENRAP_NOPELL_NOTFIRSTTIME',
         'OMAWDP8_NOPELL_NOTFIRSTTIME', 'OMENRUP_NOPELL_NOTFIRSTTIME', 'OMACHT8_NOPELL_ALL', 'OMACHT8_NOPELL_FIRSTTIME',
         'OMACHT8_NOPELL_NOTFIRSTTIME', 'BBRR4_PP_NOMALE_DISCHARGE', 'CONTROL_PEPS', 'ADM_RATE_SUPP', 'OMENRYP_NOPELL_ALL',
         'OMENRAP_NOPELL_ALL', 'OMAWDP8_NOPELL_ALL', 'OMENRUP_NOPELL_ALL', 'OMENRYP_NOPELL_FIRSTTIME', 'OMENRAP_NOPELL_FIRSTTIME',
         ], inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Columns: 3212 entries, UNITID to ADDR
# dtypes: float64(2678), int64(13), object(521)
# memory usage: 158.9+ MB

# %%
df.head(10)
# Out:
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# 2  100690  2503400.0  25034.0                   Amridge University
# 3  100706   105500.0   1055.0  University of Alabama in Huntsville
# 4  100724   100500.0   1005.0             Alabama State University
# 5  100751   105100.0   1051.0            The University of Alabama
# 6  100760   100700.0   1007.0    Central Alabama Community College
# 7  100812   100800.0   1008.0              Athens State University
# 8  100830   831000.0   8310.0      Auburn University at Montgomery
# 9  100858   100900.0   1009.0                    Auburn University
#
#              CITY STABBR         ZIP  \
# 0          Normal     AL       35762
# 1      Birmingham     AL  35294-0110
# 2      Montgomery     AL  36117-3553
# 3      Huntsville     AL       35899
# ...
