# %%
import pandas as pd
import os

# %%
# Dataset from https://collegescorecard.ed.gov/data/
#df = pd.read_csv('/Users/jessicabenitez/Downloads/Most-Recent-Cohorts-Institution.csv', 
                 #encoding='latin-1')
df = pd.read_csv('../data/Raw-Most-Recent-Cohorts-Institution.csv', 
                encoding='latin-1')
df.head(10)
#os.makedirs('../data', exist_ok=True)  
#df.to_csv('../data/Raw-Most-Recent-Cohorts-Institution.csv')
# Out:
# /var/folders/4l/q8fyjl614w1567jd1msnhymw0000gn/T/ipykernel_1971/3301906161.py:4: DtypeWarning: Columns (10,1538,1541,1543,1607,1609,1615,1616,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1630,1689,1690,1691,1692,1693,1698,1701,1704,1705,1726,1727,1728,1729,1730,1744,1816,1817,1818,1819,1824,1825,1831,1832,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1899,1910,1911,1912,1913,1914,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1984,1985,2377,2378,2404,2405,2496,2497,2498,2499,2500,2501,2502,2503,2504,2505,2506,2507,2508,2509,2510,2511,2512,2513,2514,2515,2516,2517,2518,2519,2520,2521,2522,2523,2524,2525,2526,2527,2528,2529,2530,2531,2959,3216,3232,3236,3237) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/Raw-Most-Recent-Cohorts-Institution.csv',
#    Unnamed: 0  UNITID      OPEID   OPEID6  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Columns: 3245 entries, Unnamed: 0 to ACTMT50
# dtypes: float64(852), int64(15), object(2378)
# memory usage: 160.5+ MB

# %%
# showing duplicates
df.duplicated(subset='INSTNM').sum()
# Out:
# 127

# %% [markdown]
# There are 127 duplicate rows

# %%
new_df = df[["UNITID", "INSTNM", "CITY", "STABBR", "ZIP", "ACCREDAGENCY", "SCH_DEG", "ADM_RATE_SUPP", "NPT4_PUB", "NPT4_PRIV",
             "PPTUG_EF", "C150_L4_POOLED_SUPP", "C150_L4_PELL_POOLED_SUPP", "GRAD_DEBT_MDN_SUPP",
             "PLUS_DEBT_ALL_COMP_MDPAY10_SUPP", "PLUS_DEBT_INST_COMP_MDPAY10_SUPP", "GRAD_DEBT_MDN10YR_SUPP",
             "PLUS_DEBT_INST_COMP_MD_SUPP", "PREDDEG", "UGDS_WHITE", "UGDS_BLACK", "UGDS_HISP", "UGDS_ASIAN", 
             "UGDS_AIAN", "UGDS_NHPI", "UGDS_2MOR", "UGDS_NRA", "UGDS_UNKN", "IRPS_WHITE", "IRPS_BLACK", "IRPS_HISP",
             "IRPS_ASIAN", "IRPS_AIAN", "IRPS_NHPI", "IRPS_2MOR", "IRPS_NRA", "IRPS_UNKN", "BBRR2_FED_UG_N_SUPP",
             "BBRR2_FED_UG_DFLT_SUPP", "BBRR2_FED_UG_DLNQ_SUPP", "BBRR2_FED_UG_FBR_SUPP", "BBRR2_FED_UG_DFR_SUPP", 
             "BBRR2_FED_UG_NOPROG_SUPP", "BBRR2_FED_UG_MAKEPROG_SUPP", "BBRR2_FED_UG_PAIDINFULL_SUPP", "BBRR2_FED_UG_DISCHARGE_SUPP",
             "BBRR2_FED_UGCOMP_N_SUPP", "BBRR2_FED_UGCOMP_DFLT_SUPP", "BBRR2_FED_UGCOMP_DLNQ_SUPP", "BBRR2_FED_UGCOMP_FBR_SUPP",
             "BBRR2_FED_UGCOMP_DFR_SUPP", "BBRR2_FED_UGCOMP_NOPROG_SUPP", "BBRR2_FED_UGCOMP_MAKEPROG_SUPP", "BBRR2_FED_UGCOMP_PAIDINFULL_SUPP",
             "BBRR2_FED_UGCOMP_DISCHARGE_SUPP", "PCTPELL_DCS_POOLED_SUPP", "STUFACR", "PCTFLOAN_DCS_POOLED_SUPP", "RET_FT4_POOLED_SUPP",
             "RET_PT4_POOLED_SUPP", "RET_FTL4_POOLED_SUPP", "RET_PTL4_POOLED_SUPP", "SATVR25", "SATVR75", "SATMT25", 
             "SATMT75", "ACTCM25", "ACTCM75"]]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6484 entries, 0 to 6483
# Data columns (total 68 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   UNITID                            6484 non-null   int64
#  1   INSTNM                            6484 non-null   object
#  2   CITY                              6484 non-null   object
#  3   STABBR                            6484 non-null   object
#  4   ZIP                               6484 non-null   object
#  5   ACCREDAGENCY                      6245 non-null   object
#  6   SCH_DEG                           6047 non-null   float64
#  7   ADM_RATE_SUPP                     1956 non-null   object
#  8   NPT4_PUB                          1833 non-null   float64
#  9   NPT4_PRIV                         3432 non-null   float64
#  10  PPTUG_EF                          5688 non-null   float64
# ...

# %%
new_df.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP                                       ACCREDAGENCY  SCH_DEG  \
# 0       35762  Southern Association of Colleges and Schools C...      3.0
# ...

# %%
new_df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
new_df.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP                                       ACCREDAGENCY  SCH_DEG  \
# 0       35762  Southern Association of Colleges and Schools C...      3.0
# ...

# %%
os.makedirs('../data', exist_ok=True)  
new_df.to_csv('../data/all_us_uni.csv')
